# %% [markdown]
# # This is my Juputer notebook
# important: I could not use the IBM Watson studio, dor some reasson, the platform doesn't allow me to connnect in a free account.

# %% [markdown]
# #### Name: Emerson_Goncalves
# #### Occupation: Trainee in finance
# #### Nationality: Brazilian

# %% [markdown]
# ### Why I'm interested in Data science
# *I am pationated by data science because its huge potential to explain the world, considering an amount of variables that can't be handle by coventional methods.*

# %% [markdown]
# ### This code will calculate the Volume of a cone
# #### H= hight of the cone(m)
# #### R= Radio of the base of the cone(m)
# #### V = Volume of the cone (m^2)

# %%
H = 10
R = 3
V = 3.14*((R/2)**2)*H*(1/3)

# %%
V
# Out:
# 23.55

# %% [markdown]
# | Function |   Integral |
# |----------|------------|
# | x        |     x**2/2 |
# | sin(x)   |   -cos(x)  |
# | 1/x      |     ln(x)  |
# | e^x      |     e^x    |

# %% [markdown]
# Days of week
# * Sunday
# * Monday
# * Tuesday
# * Wednesday
# * Thrusday
# * Friday
# *...
